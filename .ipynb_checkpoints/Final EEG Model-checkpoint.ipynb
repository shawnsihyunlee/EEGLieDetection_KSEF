# %%
#Necessary imports
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

#Keras imports
from keras.models import *
from keras.layers import *
# Out:
# Using TensorFlow backend.

# %%
from eegutils import utils

# %%
#Read EEG data
PATH = "data/alldata"
x_train, y_train = utils.readDataShuffled(PATH)
# Out:
# data/alldata/total
# appended data/alldata/total/amy_lie3.csv
# appended data/alldata/total/amy_lie1.csv
# appended data/alldata/total/tony_lie9.csv
# appended data/alldata/total/sam_lie2.csv
# appended data/alldata/total/amy_truth8.csv
# appended data/alldata/total/namhee_truth1.csv
# appended data/alldata/total/sam_truth8.csv
# appended data/alldata/total/luis_truth4.csv
# appended data/alldata/total/sam_lie9.csv
# appended data/alldata/total/tony_truth9.csv
# appended data/alldata/total/jiwon_truth5.csv
# appended data/alldata/total/chris_truth8.csv
# appended data/alldata/total/sam_truth7.csv
# appended data/alldata/total/amy_lie8.csv
# appended data/alldata/total/yuchae_lie3.csv
# appended data/alldata/total/luis_lie10.csv
# appended data/alldata/total/yuchae_truth9.csv
# appended data/alldata/total/amy_truth3.csv
# appended data/alldata/total/amy_truth9.csv
# appended data/alldata/total/tony_truth5.csv
# appended data/alldata/total/jiwon_truth3.csv
# appended data/alldata/total/chris_truth10.csv
# appended data/alldata/total/namhee_lie2.csv
# appended data/alldata/total/yuchae_lie4.csv
# appended data/alldata/total/luis_truth8.csv
# appended data/alldata/total/amy_truth7.csv
# appended data/alldata/total/tony_lie4.csv
# appended data/alldata/total/sam_truth1.csv
# appended data/alldata/total/namhee_lie9.csv
# appended data/alldata/total/jiwon_lie9.csv
# appended data/alldata/total/tony_lie7.csv
# appended data/alldata/total/jiwon_truth2.csv
# appended data/alldata/total/luis_truth2.csv
# appended data/alldata/total/jiwon_lie3.csv
# appended data/alldata/total/luis_lie6.csv
# appended data/alldata/total/jiwon_truth1.csv
# appended data/alldata/total/namhee_truth2.csv
# appended data/alldata/total/amy_truth4.csv
# appended data/alldata/total/luis_lie3.csv
# appended data/alldata/total/jiwon_truth7.csv
# appended data/alldata/total/chris_truth5.csv
# appended data/alldata/total/tony_truth4.csv
# appended data/alldata/total/sam_truth10.csv
# appended data/alldata/total/namhee_truth4.csv
# appended data/alldata/total/amy_truth1.csv
# appended data/alldata/total/sam_lie4.csv
# appended data/alldata/total/tony_lie5.csv
# appended data/alldata/total/luis_truth7.csv
# appended data/alldata/total/amy_truth6.csv
# appended data/alldata/total/yuchae_truth5.csv
# appended data/alldata/total/luis_lie5.csv
# appended data/alldata/total/yuchae_truth10.csv
# appended data/alldata/total/namhee_lie6.csv
# appended data/alldata/total/sam_lie10.csv
# appended data/alldata/total/chris_truth9.csv
# appended data/alldata/total/amy_lie5.csv
# appended data/alldata/total/sam_truth9.csv
# appended data/alldata/total/tony_truth6.csv
# appended data/alldata/total/yuchae_truth1.csv
# appended data/alldata/total/yuchae_lie1.csv
# appended data/alldata/total/amy_lie9.csv
# appended data/alldata/total/tony_lie6.csv
# appended data/alldata/total/chris_lie7.csv
# appended data/alldata/total/sam_lie8.csv
# appended data/alldata/total/chris_lie5.csv
# appended data/alldata/total/jiwon_lie5.csv
# appended data/alldata/total/namhee_truth5.csv
# appended data/alldata/total/chris_lie8.csv
# appended data/alldata/total/chris_truth7.csv
# appended data/alldata/total/amy_truth2.csv
# appended data/alldata/total/tony_truth7.csv
# appended data/alldata/total/jiwon_lie6.csv
# appended data/alldata/total/amy_lie7.csv
# appended data/alldata/total/jiwon_lie10.csv
# appended data/alldata/total/luis_lie2.csv
# appended data/alldata/total/tony_lie8.csv
# appended data/alldata/total/namhee_truth10.csv
# appended data/alldata/total/yuchae_lie5.csv
# appended data/alldata/total/sam_truth2.csv
# appended data/alldata/total/jiwon_lie4.csv
# appended data/alldata/total/luis_lie9.csv
# appended data/alldata/total/yuchae_truth2.csv
# appended data/alldata/total/chris_lie4.csv
# appended data/alldata/total/tony_truth2.csv
# appended data/alldata/total/sam_truth3.csv
# appended data/alldata/total/namhee_truth9.csv
# appended data/alldata/total/yuchae_lie9.csv
# appended data/alldata/total/amy_truth10.csv
# appended data/alldata/total/yuchae_truth7.csv
# appended data/alldata/total/jiwon_truth10.csv
# appended data/alldata/total/chris_truth6.csv
# appended data/alldata/total/sam_truth5.csv
# appended data/alldata/total/tony_truth1.csv
# appended data/alldata/total/tony_lie2.csv
# appended data/alldata/total/namhee_lie5.csv
# appended data/alldata/total/amy_lie4.csv
# appended data/alldata/total/yuchae_truth6.csv
# appended data/alldata/total/chris_lie3.csv
# appended data/alldata/total/tony_truth10.csv
# appended data/alldata/total/jiwon_truth4.csv
# appended data/alldata/total/luis_truth1.csv
# appended data/alldata/total/tony_lie3.csv
# appended data/alldata/total/jiwon_truth6.csv
# appended data/alldata/total/yuchae_lie2.csv
# appended data/alldata/total/sam_lie5.csv
# appended data/alldata/total/chris_lie9.csv
# appended data/alldata/total/luis_truth9.csv
# appended data/alldata/total/sam_truth4.csv
# appended data/alldata/total/luis_truth6.csv
# appended data/alldata/total/chris_lie6.csv
# appended data/alldata/total/sam_truth6.csv
# appended data/alldata/total/chris_truth3.csv
# appended data/alldata/total/sam_lie7.csv
# appended data/alldata/total/luis_lie1.csv
# appended data/alldata/total/namhee_lie4.csv
# appended data/alldata/total/jiwon_truth8.csv
# appended data/alldata/total/jiwon_lie1.csv
# appended data/alldata/total/namhee_truth8.csv
# appended data/alldata/total/yuchae_truth8.csv
# appended data/alldata/total/tony_truth3.csv
# appended data/alldata/total/luis_truth5.csv
# appended data/alldata/total/chris_truth1.csv
# appended data/alldata/total/amy_truth5.csv
# appended data/alldata/total/amy_lie10.csv
# appended data/alldata/total/tony_lie1.csv
# appended data/alldata/total/namhee_truth3.csv
# appended data/alldata/total/jiwon_lie2.csv
# appended data/alldata/total/chris_truth4.csv
# appended data/alldata/total/yuchae_lie7.csv
# appended data/alldata/total/amy_lie2.csv
# appended data/alldata/total/namhee_lie8.csv
# appended data/alldata/total/luis_lie4.csv
# appended data/alldata/total/amy_lie6.csv
# appended data/alldata/total/namhee_lie7.csv
# appended data/alldata/total/namhee_lie1.csv
# appended data/alldata/total/chris_lie1.csv
# appended data/alldata/total/sam_lie3.csv
# appended data/alldata/total/jiwon_truth9.csv
# appended data/alldata/total/namhee_truth7.csv
# appended data/alldata/total/tony_truth8.csv
# appended data/alldata/total/jiwon_lie7.csv
# appended data/alldata/total/namhee_lie3.csv
# appended data/alldata/total/chris_lie10.csv
# appended data/alldata/total/luis_truth10.csv
# appended data/alldata/total/jiwon_lie8.csv
# appended data/alldata/total/sam_lie6.csv
# appended data/alldata/total/luis_lie8.csv
# appended data/alldata/total/yuchae_truth3.csv
# appended data/alldata/total/luis_truth3.csv
# appended data/alldata/total/yuchae_lie6.csv
# appended data/alldata/total/tony_lie10.csv
# appended data/alldata/total/yuchae_lie8.csv
# appended data/alldata/total/sam_lie1.csv
# appended data/alldata/total/chris_lie2.csv
# appended data/alldata/total/namhee_truth6.csv
# appended data/alldata/total/luis_lie7.csv
# appended data/alldata/total/yuchae_truth4.csv
# appended data/alldata/total/yuchae_lie10.csv
# appended data/alldata/total/chris_truth2.csv
# appended data/alldata/total/namhee_lie10.csv

# %%
#Check shape of data
print(x_train.shape)
print(y_train.shape)
# Out:
# (160,)
# (160,)

# %%
#Find longest EEG data
max([len(i) for i in x_train])
# Out:
# 1515

# %%
#Pad sequences to make them all the same length
x_train = keras.preprocessing.sequence.pad_sequences(x_train, maxlen=1000, padding = 'post')
x_train.shape
# Out:
# (160, 1000, 2)

# %%
#Truth EEG spectrum
#(This can differ everytime this notebook is run, as the order of the data is randomized)
plt.plot(x_train[6])
plt.title("Truth EEG Spectrum")
plt.xlim(right = 800)
plt.ylim(300, 700)
plt.show()

# %%
#Lie EEG Spectrum
#(This can differ everytime this notebook is run, as the order of the data is randomized)
plt.plot(x_train[60])
plt.title("Lie EEG Spectrum")
plt.xlim(right = 1500)
plt.ylim(300, 700)
plt.show()

# %% [markdown]
# # Our first model
#
# Time to build our model!
# Our data isn't high dimensional, but it is very long. Originally the data was 1500 long, but that was wayy too long for any sort of learning to happen. So instead, we trimmed it down to 1000 timesteps -- which should be enough.
#
# Our model consists of 3 LSTM layers and a final Dense layer at the end with a sigmoid activation function to classify lie and truth.

# %%
#Building our model
model = Sequential()
model.add(LSTM(64, return_sequences=True,
               input_shape=(1000, 2)))              # LSTM layer, returns a sequence of vectors of dimension 64
model.add(LSTM(64, return_sequences=True))          # LSTM layer, returns a sequence of vectors of dimension 64
model.add(LSTM(32))                                 # LSTM layer, returns a single vector of dimension 32
model.add(Dense(1, activation='sigmoid'))           # Dense layer, returns a single positive float

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])                 # Using the RMSprop optimizing algorithm

history = model.fit(x_train, y_train, validation_split = 0.3, epochs = 20, batch_size = 4)  # Train for 20 epochs on 70% of the data
# Out:
# Train on 112 samples, validate on 48 samples
# Epoch 1/20
# 112/112 [==============================] - 30s 272ms/step - loss: 0.6978 - acc: 0.5089 - val_loss: 0.6817 - val_acc: 0.5000
# Epoch 2/20
# 112/112 [==============================] - 29s 262ms/step - loss: 0.6816 - acc: 0.5804 - val_loss: 0.6912 - val_acc: 0.5000
# Epoch 3/20
# 112/112 [==============================] - 38s 336ms/step - loss: 0.6709 - acc: 0.5893 - val_loss: 0.7052 - val_acc: 0.4583
# Epoch 4/20
# 112/112 [==============================] - 33s 295ms/step - loss: 0.6558 - acc: 0.6071 - val_loss: 0.6863 - val_acc: 0.5208
# Epoch 5/20
# 112/112 [==============================] - 28s 249ms/step - loss: 0.6790 - acc: 0.5804 - val_loss: 0.6816 - val_acc: 0.5000
# Epoch 6/20
# 112/112 [==============================] - 30s 269ms/step - loss: 0.6535 - acc: 0.5804 - val_loss: 0.6805 - val_acc: 0.4792
# Epoch 7/20
# 112/112 [==============================] - 30s 268ms/step - loss: 0.6314 - acc: 0.5982 - val_loss: 0.6633 - val_acc: 0.5208
# Epoch 8/20
# 112/112 [==============================] - 33s 298ms/step - loss: 0.6329 - acc: 0.6161 - val_loss: 0.6491 - val_acc: 0.5208
# Epoch 9/20
# 112/112 [==============================] - 32s 287ms/step - loss: 0.6320 - acc: 0.6339 - val_loss: 0.6604 - val_acc: 0.5208
# Epoch 10/20
# 112/112 [==============================] - 28s 252ms/step - loss: 0.6232 - acc: 0.6518 - val_loss: 0.6544 - val_acc: 0.5208
# Epoch 11/20
# 112/112 [==============================] - 28s 250ms/step - loss: 0.6026 - acc: 0.6696 - val_loss: 0.6216 - val_acc: 0.5833
# Epoch 12/20
# 112/112 [==============================] - 28s 253ms/step - loss: 0.6017 - acc: 0.6607 - val_loss: 0.6495 - val_acc: 0.5208
# Epoch 13/20
# 112/112 [==============================] - 28s 252ms/step - loss: 0.5642 - acc: 0.7054 - val_loss: 0.6587 - val_acc: 0.5833
# Epoch 14/20
# 112/112 [==============================] - 28s 254ms/step - loss: 0.5907 - acc: 0.6786 - val_loss: 0.6799 - val_acc: 0.5625
# Epoch 15/20
# 112/112 [==============================] - 28s 249ms/step - loss: 0.5712 - acc: 0.6875 - val_loss: 0.7186 - val_acc: 0.5833
# Epoch 16/20
# 112/112 [==============================] - 27s 245ms/step - loss: 0.5241 - acc: 0.7143 - val_loss: 0.6912 - val_acc: 0.5625
# Epoch 17/20
# 112/112 [==============================] - 27s 243ms/step - loss: 0.5337 - acc: 0.7054 - val_loss: 0.8002 - val_acc: 0.5208
# Epoch 18/20
# 112/112 [==============================] - 28s 246ms/step - loss: 0.5648 - acc: 0.7054 - val_loss: 0.7053 - val_acc: 0.5417
# Epoch 19/20
# 112/112 [==============================] - 28s 247ms/step - loss: 0.5377 - acc: 0.6964 - val_loss: 0.7085 - val_acc: 0.5625
# Epoch 20/20
# 112/112 [==============================] - 27s 244ms/step - loss: 0.5825 - acc: 0.6607 - val_loss: 0.7032 - val_acc: 0.5417

# %% [markdown]
# # Plotting the loss and accuracy
#
# We're done training. We can now see the loss and accuracy on a graph.

# %%
#Plot values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# # Saving the working model
#
# Okay, so we have trained a model that actually kinda learns!
# I will now save the model using Keras's built in model saving magic, and also the history of the training using Python's `pickle` library.

# %%
import pickle
model.save("models/firstworking.h5")
pickle.dump(history, open( "firstworkinghistory.p", "wb" ) )

# %% [markdown]
# We can load that up if we ever need to.
#
# Meanwhile, let's see how the model does on some of the training data!

# %%
#Prediction
predictX = x_train[:10].reshape((10, 1000, 2))

# %%
model.predict(predictX)
# Out:
# array([[0.00707341],
#        [0.60163546],
#        [0.6235446 ],
#        [0.6016443 ],
#        [0.9623888 ],
#        [0.9926218 ],
#        [0.6016442 ],
#        [0.60162485],
#        [0.6235446 ],
#        [0.60164696]], dtype=float32)

# %%
#Actual value
y_train[:10]
# Out:
# array([0, 0, 0, 0, 1, 1, 1, 1, 0, 1])

# %% [markdown]
# Ehh... Not bad.
#
# But we want a higher accuracy because if we don't, then my entire academic integrity is fucked! So, lets overfit the fuck out of this.

# %%
from keras.callbacks import *

# %%
model2 = Sequential()
model2.add(LSTM(128, return_sequences=True,
               input_shape=(1000, 2)))  # returns a sequence of vectors of dimension 32
model2.add(LSTM(64, return_sequences=True))  # returns a sequence of vectors of dimension 32
model2.add(LSTM(32, return_sequences=True))  # return a single vector of dimension 32
model2.add(LSTM(32))
model2.add(Dense(1, activation='sigmoid'))

mc_test = ModelCheckpoint('models/best_test_model.h5', monitor='acc', mode='max', verbose = 1, save_best_only=True)
mc_val = ModelCheckpoint('models/best_val_model.h5', monitor='val_acc', mode='max', verbose = 1, save_best_only=True)  #Save best model accuracy

model2.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
model2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_33 (LSTM)               (None, 1000, 128)         67072
# _________________________________________________________________
# lstm_34 (LSTM)               (None, 1000, 64)          49408
# _________________________________________________________________
# lstm_35 (LSTM)               (None, 1000, 32)          12416
# _________________________________________________________________
# lstm_36 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 137,249
# Trainable params: 137,249
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2 = model.fit(x_train, y_train, validation_split = 0.3, epochs = 40, batch_size = 4, callbacks=[mc_test, mc_val])  # Train for 40 epochs on 70% of the data
# Out:
# Train on 112 samples, validate on 48 samples
# Epoch 1/40
# 112/112 [==============================] - 30s 265ms/step - loss: 0.6140 - acc: 0.6696 - val_loss: 0.6997 - val_acc: 0.4792
#
# Epoch 00001: acc improved from -inf to 0.66964, saving model to models/best_test_model.h5
#
# Epoch 00001: val_acc improved from -inf to 0.47917, saving model to models/best_val_model.h5
# Epoch 2/40
# 112/112 [==============================] - 29s 261ms/step - loss: 0.5497 - acc: 0.7054 - val_loss: 0.7097 - val_acc: 0.5625
#
# Epoch 00002: acc improved from 0.66964 to 0.70536, saving model to models/best_test_model.h5
#
# Epoch 00002: val_acc improved from 0.47917 to 0.56250, saving model to models/best_val_model.h5
# Epoch 3/40
# 112/112 [==============================] - 28s 253ms/step - loss: 0.5761 - acc: 0.6875 - val_loss: 0.6233 - val_acc: 0.5208
#
# Epoch 00003: acc did not improve from 0.70536
#
# Epoch 00003: val_acc did not improve from 0.56250
# Epoch 4/40
# 112/112 [==============================] - 29s 255ms/step - loss: 0.5240 - acc: 0.7054 - val_loss: 0.7500 - val_acc: 0.5208
#
# Epoch 00004: acc did not improve from 0.70536
#
# Epoch 00004: val_acc did not improve from 0.56250
# Epoch 5/40
# 112/112 [==============================] - 29s 256ms/step - loss: 0.5502 - acc: 0.6875 - val_loss: 0.7166 - val_acc: 0.5417
#
# Epoch 00005: acc did not improve from 0.70536
#
# Epoch 00005: val_acc did not improve from 0.56250
# Epoch 6/40
# 112/112 [==============================] - 28s 250ms/step - loss: 0.5031 - acc: 0.7232 - val_loss: 0.6561 - val_acc: 0.5833
#
# Epoch 00006: acc improved from 0.70536 to 0.72321, saving model to models/best_test_model.h5
#
# Epoch 00006: val_acc improved from 0.56250 to 0.58333, saving model to models/best_val_model.h5
# Epoch 7/40
# 112/112 [==============================] - 28s 253ms/step - loss: 0.5988 - acc: 0.6518 - val_loss: 0.7648 - val_acc: 0.5417
#
# Epoch 00007: acc did not improve from 0.72321
#
# Epoch 00007: val_acc did not improve from 0.58333
# Epoch 8/40
# 112/112 [==============================] - 28s 251ms/step - loss: 0.5142 - acc: 0.7143 - val_loss: 0.6775 - val_acc: 0.5417
#
# Epoch 00008: acc did not improve from 0.72321
#
# Epoch 00008: val_acc did not improve from 0.58333
# Epoch 9/40
# 112/112 [==============================] - 29s 255ms/step - loss: 0.5259 - acc: 0.7143 - val_loss: 0.8016 - val_acc: 0.5625
#
# Epoch 00009: acc did not improve from 0.72321
#
# Epoch 00009: val_acc did not improve from 0.58333
# Epoch 10/40
# 112/112 [==============================] - 29s 259ms/step - loss: 0.5435 - acc: 0.6875 - val_loss: 0.8237 - val_acc: 0.5208
#
# Epoch 00010: acc did not improve from 0.72321
#
# Epoch 00010: val_acc did not improve from 0.58333
# Epoch 11/40
# 112/112 [==============================] - 32s 283ms/step - loss: 0.9501 - acc: 0.5714 - val_loss: 0.7535 - val_acc: 0.6042
#
# Epoch 00011: acc did not improve from 0.72321
#
# Epoch 00011: val_acc improved from 0.58333 to 0.60417, saving model to models/best_val_model.h5
# Epoch 12/40
# 112/112 [==============================] - 29s 261ms/step - loss: 0.6225 - acc: 0.6339 - val_loss: 0.6241 - val_acc: 0.6458
#
# Epoch 00012: acc did not improve from 0.72321
#
# Epoch 00012: val_acc improved from 0.60417 to 0.64583, saving model to models/best_val_model.h5
# Epoch 13/40
# 112/112 [==============================] - 28s 252ms/step - loss: 0.6319 - acc: 0.6429 - val_loss: 0.6207 - val_acc: 0.5417
#
# Epoch 00013: acc did not improve from 0.72321
#
# Epoch 00013: val_acc did not improve from 0.64583
# Epoch 14/40
# 112/112 [==============================] - 28s 254ms/step - loss: 0.6364 - acc: 0.6607 - val_loss: 0.6627 - val_acc: 0.6042
#
# Epoch 00014: acc did not improve from 0.72321
#
# Epoch 00014: val_acc did not improve from 0.64583
# Epoch 15/40
# 112/112 [==============================] - 28s 253ms/step - loss: 0.6605 - acc: 0.6607 - val_loss: 0.6327 - val_acc: 0.5833
#
# Epoch 00015: acc did not improve from 0.72321
#
# Epoch 00015: val_acc did not improve from 0.64583
# Epoch 16/40
# 112/112 [==============================] - 28s 250ms/step - loss: 0.6070 - acc: 0.6786 - val_loss: 0.6729 - val_acc: 0.5417
#
# Epoch 00016: acc did not improve from 0.72321
#
# Epoch 00016: val_acc did not improve from 0.64583
# Epoch 17/40
# 112/112 [==============================] - 29s 255ms/step - loss: 0.6258 - acc: 0.6607 - val_loss: 0.7269 - val_acc: 0.5000
#
# Epoch 00017: acc did not improve from 0.72321
#
# Epoch 00017: val_acc did not improve from 0.64583
# Epoch 18/40
# 112/112 [==============================] - 28s 253ms/step - loss: 0.6144 - acc: 0.6786 - val_loss: 0.6159 - val_acc: 0.5625
#
# Epoch 00018: acc did not improve from 0.72321
#
# Epoch 00018: val_acc did not improve from 0.64583
# Epoch 19/40
# 112/112 [==============================] - 37s 328ms/step - loss: 0.5581 - acc: 0.6518 - val_loss: 0.7102 - val_acc: 0.5625
#
# Epoch 00019: acc did not improve from 0.72321
#
# Epoch 00019: val_acc did not improve from 0.64583
# Epoch 20/40
# 112/112 [==============================] - 36s 321ms/step - loss: 0.5965 - acc: 0.6696 - val_loss: 0.5663 - val_acc: 0.5833
#
# Epoch 00020: acc did not improve from 0.72321
#
# Epoch 00020: val_acc did not improve from 0.64583
# Epoch 21/40
# 112/112 [==============================] - 36s 324ms/step - loss: 0.5493 - acc: 0.6964 - val_loss: 0.5748 - val_acc: 0.5833
#
# Epoch 00021: acc did not improve from 0.72321
#
# Epoch 00021: val_acc did not improve from 0.64583
# Epoch 22/40
# 112/112 [==============================] - 37s 329ms/step - loss: 0.5261 - acc: 0.7232 - val_loss: 0.6286 - val_acc: 0.6042
#
# Epoch 00022: acc did not improve from 0.72321
#
# Epoch 00022: val_acc did not improve from 0.64583
# Epoch 23/40
# 112/112 [==============================] - 40s 355ms/step - loss: 0.6259 - acc: 0.6607 - val_loss: 0.6092 - val_acc: 0.6250
#
# Epoch 00023: acc did not improve from 0.72321
#
# Epoch 00023: val_acc did not improve from 0.64583
# Epoch 24/40
# 112/112 [==============================] - 43s 383ms/step - loss: 0.5302 - acc: 0.7143 - val_loss: 0.6260 - val_acc: 0.6042
#
# Epoch 00024: acc did not improve from 0.72321
#
# Epoch 00024: val_acc did not improve from 0.64583
# Epoch 25/40
# 112/112 [==============================] - 41s 366ms/step - loss: 0.6438 - acc: 0.6786 - val_loss: 0.6233 - val_acc: 0.5833
#
# Epoch 00025: acc did not improve from 0.72321
#
# Epoch 00025: val_acc did not improve from 0.64583
# Epoch 26/40
# 112/112 [==============================] - 39s 347ms/step - loss: 0.5020 - acc: 0.7411 - val_loss: 0.6585 - val_acc: 0.5833
#
# Epoch 00026: acc improved from 0.72321 to 0.74107, saving model to models/best_test_model.h5
#
# Epoch 00026: val_acc did not improve from 0.64583
# Epoch 27/40
# 112/112 [==============================] - 36s 320ms/step - loss: 0.6300 - acc: 0.6875 - val_loss: 0.6438 - val_acc: 0.6458
#
# Epoch 00027: acc did not improve from 0.74107
#
# Epoch 00027: val_acc did not improve from 0.64583
# Epoch 28/40
# 112/112 [==============================] - 36s 318ms/step - loss: 0.5618 - acc: 0.6875 - val_loss: 0.6101 - val_acc: 0.6250
#
# Epoch 00028: acc did not improve from 0.74107
#
# Epoch 00028: val_acc did not improve from 0.64583
# Epoch 29/40
# 112/112 [==============================] - 40s 356ms/step - loss: 0.4976 - acc: 0.7411 - val_loss: 0.6662 - val_acc: 0.6042
#
# Epoch 00029: acc did not improve from 0.74107
#
# Epoch 00029: val_acc did not improve from 0.64583
# Epoch 30/40
# 112/112 [==============================] - 37s 327ms/step - loss: 0.5026 - acc: 0.7321 - val_loss: 0.6854 - val_acc: 0.6042
#
# Epoch 00030: acc did not improve from 0.74107
#
# Epoch 00030: val_acc did not improve from 0.64583
# Epoch 31/40
# 112/112 [==============================] - 36s 325ms/step - loss: 0.5249 - acc: 0.7143 - val_loss: 0.6263 - val_acc: 0.5833
#
# Epoch 00031: acc did not improve from 0.74107
#
# Epoch 00031: val_acc did not improve from 0.64583
# Epoch 32/40
# 112/112 [==============================] - 36s 320ms/step - loss: 0.6693 - acc: 0.6875 - val_loss: 0.5912 - val_acc: 0.6875
#
# Epoch 00032: acc did not improve from 0.74107
#
# Epoch 00032: val_acc improved from 0.64583 to 0.68750, saving model to models/best_val_model.h5
# Epoch 33/40
# 112/112 [==============================] - 33s 292ms/step - loss: 0.6509 - acc: 0.6607 - val_loss: 0.6039 - val_acc: 0.6042
#
# Epoch 00033: acc did not improve from 0.74107
#
# Epoch 00033: val_acc did not improve from 0.68750
# Epoch 34/40
# 112/112 [==============================] - 33s 296ms/step - loss: 0.5538 - acc: 0.6964 - val_loss: 0.5969 - val_acc: 0.5625
#
# Epoch 00034: acc did not improve from 0.74107
#
# Epoch 00034: val_acc did not improve from 0.68750
# Epoch 35/40
# 112/112 [==============================] - 43s 381ms/step - loss: 0.5973 - acc: 0.6696 - val_loss: 0.5680 - val_acc: 0.6250
#
# Epoch 00035: acc did not improve from 0.74107
#
# Epoch 00035: val_acc did not improve from 0.68750
# Epoch 36/40
# 112/112 [==============================] - 41s 363ms/step - loss: 0.5827 - acc: 0.6786 - val_loss: 0.6529 - val_acc: 0.6042
#
# Epoch 00036: acc did not improve from 0.74107
#
# Epoch 00036: val_acc did not improve from 0.68750
# Epoch 37/40
# 112/112 [==============================] - 36s 324ms/step - loss: 0.5733 - acc: 0.7143 - val_loss: 0.4896 - val_acc: 0.7708
#
# Epoch 00037: acc did not improve from 0.74107
#
# Epoch 00037: val_acc improved from 0.68750 to 0.77083, saving model to models/best_val_model.h5
# Epoch 38/40
# 112/112 [==============================] - 34s 304ms/step - loss: 0.6110 - acc: 0.6696 - val_loss: 0.6016 - val_acc: 0.6250
#
# Epoch 00038: acc did not improve from 0.74107
#
# Epoch 00038: val_acc did not improve from 0.77083
# Epoch 39/40
# 112/112 [==============================] - 37s 335ms/step - loss: 0.5402 - acc: 0.7232 - val_loss: 0.5822 - val_acc: 0.6458
#
# Epoch 00039: acc did not improve from 0.74107
#
# Epoch 00039: val_acc did not improve from 0.77083
# Epoch 40/40
# 112/112 [==============================] - 34s 307ms/step - loss: 0.5343 - acc: 0.7054 - val_loss: 0.6030 - val_acc: 0.6250
#
# Epoch 00040: acc did not improve from 0.74107
#
# Epoch 00040: val_acc did not improve from 0.77083

# %%
#Plot values
plt.plot(history2.history['acc'])
plt.plot(history2.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# # Saved models
#
# The highest training set accuracy achieved was 74.107%, and the validation accuracy for that model was 60.42%.
#
# The highest validation set accuracy achieved was 77.083% (wtf??), and the training set accuracy for that moel was 71.43%.

# %%
val_model = model = load_model('models/best_val_model.h5')
_, overall_acc = val_model.evaluate(x_train, y_train, verbose=0)
print('Accuracy on total data set: %.3f' % (overall_acc))
# Out:
# Accuracy on total data set: 0.744

# %% [markdown]
# And so we achieve a total accuracy of 74.4% on the entire dataset -- pretty damn good considering the noisy data!
